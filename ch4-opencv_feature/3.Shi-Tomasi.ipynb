# %% [markdown]
# ## Shi-tomas
# 修改了harris的角点检测阈值?或者说检测标准,算法没改
# 此功能更适合跟踪

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('../data/blox.jpg')
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
corners = cv.goodFeaturesToTrack(gray,25,0.01,10)
corners = np.int0(corners)
for i in corners:
    x,y = i.ravel()
    cv.circle(img,(x,y),3,255,-1)
plt.imshow(img),plt.show()
# Out:
# C:\Users\28678\AppData\Local\Temp\ipykernel_38024\3749661884.py:7: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)
# (<matplotlib.image.AxesImage at 0x1e8efb3f850>, None)
